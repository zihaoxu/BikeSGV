# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('max_column', 100)

# %%
import_path = '/Users/zihaoxu/R_repos/sgv_bike/import/'
dataset_path = '/Users/zihaoxu/R_repos/sgv_bike/datasets/'

# %%
# Read in the data
df = pd.read_csv(import_path + 'ped.csv')
print(list(df))
df.head()
# Out:
# ['IntervalID', 'location_ID', 'street1', 'street2', 'street3', 'latitude', 'longitude', 'type', 'Date', 'Day', 'period_begin', 'period_end', 'Interval_Begin', 'NS', 'SN', 'EW', 'WE', 'SpecialNeeds', 'Skate', 'Child', 'Other_Var1', 'Other_Var2', 'Other_Var1_Count', 'Other_Var2_Count', 'Count_Method', 'raining', 'unusual', 'bikewaytype', 'bikewaytype_options', 'road_class', 'speed_limit', 'landuse', 'pk_dataset_id', 'dataset_name', 'pk_physicalenv_id', 'pk_countocc_id', 'createdatetime', 'username']
#    IntervalID  location_ID       street1           street2    street3  \
# 0     17560.0       1025.0  Durfee Ave.   Santa Anita Ave.  Peck Rd.
# 1     17561.0       1025.0  Durfee Ave.   Santa Anita Ave.  Peck Rd.
# 2     17562.0       1025.0  Durfee Ave.   Santa Anita Ave.  Peck Rd.
# 3     17563.0       1025.0  Durfee Ave.   Santa Anita Ave.  Peck Rd.
# 4     17564.0       1025.0  Durfee Ave.   Santa Anita Ave.  Peck Rd.
#
#     latitude   longitude      type        Date       Day period_begin  \
# 0  34.035943 -118.039993  midblock  12-03-2016  Saturday     11:00 AM
# 1  34.035943 -118.039993  midblock  12-03-2016  Saturday     11:00 AM
# 2  34.035943 -118.039993  midblock  12-03-2016  Saturday     11:00 AM
# 3  34.035943 -118.039993  midblock  12-03-2016  Saturday     11:00 AM
# 4  34.035943 -118.039993  midblock  12-03-2016  Saturday     11:00 AM
#
#   period_end Interval_Begin  NS  SN  EW  WE  SpecialNeeds  Skate  Child  \
# 0    1:00 AM       11:00 AM   0   0   4   7             0      1      2
# 1    1:00 AM       11:15 AM   0   0   0   0             0      0      0
# 2    1:00 AM       11:30 AM   0   0   2   5             0      0      0
# 3    1:00 AM       11:45 AM   0   0   1   3             0      0      0
# 4    1:00 AM       12:00 PM   0   0   1   0             0      0      0
#
#   Other_Var1 Other_Var2  Other_Var1_Count  Other_Var2_Count     Count_Method  \
# 0        NaN        NaN               0.0               0.0  manual_in_house
# 1        NaN        NaN               0.0               0.0  manual_in_house
# 2        NaN        NaN               0.0               0.0  manual_in_house
# 3        NaN        NaN               0.0               0.0  manual_in_house
# 4        NaN        NaN               0.0               0.0  manual_in_house
#
#   raining  unusual bikewaytype bikewaytype_options     road_class  \
# 0      no      NaN        none                 NaN  minorArterial
# 1      no      NaN        none                 NaN  minorArterial
# 2      no      NaN        none                 NaN  minorArterial
# 3      no      NaN        none                 NaN  minorArterial
# 4      no      NaN        none                 NaN  minorArterial
#
#    speed_limit             landuse  pk_dataset_id dataset_name  \
# 0         40.0  neighborhoodRetail          133.0  BikeSGV SEM
# 1         40.0  neighborhoodRetail          133.0  BikeSGV SEM
# 2         40.0  neighborhoodRetail          133.0  BikeSGV SEM
# 3         40.0  neighborhoodRetail          133.0  BikeSGV SEM
# 4         40.0  neighborhoodRetail          133.0  BikeSGV SEM
#
#    pk_physicalenv_id  pk_countocc_id       createdatetime         username
# 0             1557.0          2893.0  2017-07-17 15:08:00  wes@bikesgv.org
# 1             1557.0          2893.0  2017-07-17 15:08:00  wes@bikesgv.org
# 2             1557.0          2893.0  2017-07-17 15:08:00  wes@bikesgv.org
# 3             1557.0          2893.0  2017-07-17 15:08:00  wes@bikesgv.org
# 4             1557.0          2893.0  2017-07-17 15:08:00  wes@bikesgv.org

# %%
# Drop useless columns
df = df.drop(['type', 'username', 'pk_physicalenv_id', 'pk_countocc_id'], 1)

# Consistent naming: lowercase
df.columns = [c.lower() for c in df.columns]
df = df.rename(columns = {'day':'weekday'})

# %%
# First look at the data types
df.dtypes.sort_values()
# Out:
# specialneeds             int64
# child                    int64
# skate                    int64
# we                       int64
# ew                       int64
# sn                       int64
# ns                       int64
# pk_dataset_id          float64
# speed_limit            float64
# unusual                float64
# other_var2_count       float64
# other_var1_count       float64
# intervalid             float64
# location_id            float64
# longitude              float64
# latitude               float64
# period_end              object
# landuse                 object
# street1                 object
# road_class              object
# bikewaytype_options     object
# bikewaytype             object
# street2                 object
# raining                 object
# count_method            object
# street3                 object
# other_var2              object
# other_var1              object
# date                    object
# dataset_name            object
# weekday                 object
# period_begin            object
# interval_begin          object
# createdatetime          object
# dtype: object

# %%
# Change createdatetime to dtype of datetime
df['createdatetime'] = pd.to_datetime(df['createdatetime'])

# %%
df.to_csv(dataset_path + 'raw/ped.csv', index = None)
